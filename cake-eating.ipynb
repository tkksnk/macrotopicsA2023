# %%
# parameter
β = 0.9                        # discount factor

# set grid
nw = 1001                      # number of grid points
wgrid = collect(range(0.0,stop=1.0,length=nw)) # evenly spaced grid points from 0.0 to 1.0
wgrid[1] = wgrid[2]/10         # avoid w=c=0

# analytical solution
B = 1/(1-β)
A = (β*B*log(β*B)-(1+β*B)*log(1+β*B))/(1-β)
vvec = A .+ B*log.(wgrid)      # value function
wvec = β*wgrid                 # policy function
# Out:
# 1001-element Vector{Float64}:
#  9.0e-5
#  0.0009000000000000001
#  0.0018000000000000002
#  0.0027
#  0.0036000000000000003
#  0.0045000000000000005
#  0.0054
#  0.0063
#  0.007200000000000001
#  0.0081
#  0.009000000000000001
#  0.009899999999999999
#  0.0108
#  ⋮
#  0.8901
#  0.891
#  0.8919
#  0.8928
#  0.8937
#  0.8946000000000001
#  0.8955
#  0.8964
#  0.8973
#  0.8982
#  0.8991
#  0.9

# %%
# 0. construct the current utility
umat = zeros(nw,nw)
for iw in 1:nw # today's wealth
    for jw in 1:nw # tomorrow's wealth
        wnow = wgrid[iw]  # W
        wp = wgrid[jw]    # W'
        cnow = wnow-wp      # c=W-W'
        if cnow>0
            # if c >0, the utility value is log(c)
            umat[iw,jw] = log(cnow)
        else
            # if c<=0, the utility value is set so that the index j is never chosen. 
            umat[iw,jw] = -1e+10 # -10000000000 (i.e., ten zeros)
        end
    end
end

# NOTE: to avoid log(0) when wnow=wp=0
umat[1,1] = log(wgrid[1])
# Out:
# -9.210340371976182

# %%
wvec0 = zeros(nw)     # policy function
vvec0 = zeros(nw)     # old value function
vvec1 = zeros(nw)     # new value function

diff = 1e+4
iter = 0

while diff>1e-4 # while loop until the condition diff>1e-4 met

    for iw in 1:nw # for each index of the current period, iw=0,...,nw-1    
        # 1. find the index of the next period jw so as to maximize the value function
        jw = argmax(umat[iw,:] + β*vvec0)
        vvec1[iw] = umat[iw,jw] + β*vvec0[jw]   # V*(W)
        wvec0[iw] = wgrid[jw]                   # W'(W)
    end

    diff  = maximum(abs.(vvec1-vvec0)) # the condition for convergence
    iter  = iter + 1
    println([iter,diff])
    # 2. update the value function
    vvec0 = copy(vvec1)
    
end
# Out:
# [1.0, 9.210340371976182]
# [2.0, 8.289306334778564]
# [3.0, 7.460375701300709]
# [4.0, 6.7143381311706385]
# [5.0, 6.042904318053573]
# [6.0, 5.43861388624822]
# [7.0, 4.894752497623401]
# [8.0, 4.405277247861058]
# [9.0, 3.964749523074957]
# [10.0, 3.568274570767464]
# [11.0, 3.211447113690717]
# [12.0, 2.8903024023216446]
# [13.0, 2.6012721620894865]
# [14.0, 2.3411449458805365]
# [15.0, 2.1070304512924807]
# [16.0, 1.8963274061632376]
# [17.0, 1.7066946655469195]
# [18.0, 1.5360251989922347]
# [19.0, 1.3824226790930112]
# [20.0, 1.244180411183713]
# [21.0, 1.1197623700653452]
# [22.0, 1.007786133058815]
# [23.0, 0.9070075197529377]
# [24.0, 0.8163067677776468]
# [25.0, 0.7346760909998835]
# [26.0, 0.661208481899898]
# [27.0, 0.5950876337099089]
# [28.0, 0.5355788703389237]
# [29.0, 0.4820209833050342]
# [30.0, 0.43381888497454213]
# [31.0, 0.3904369964770922]
# [32.0, 0.3513932968293858]
# [33.0, 0.3162539671464515]
# [34.0, 0.28462857043180634]
# [35.0, 0.2561657133886257]
# [36.0, 0.2305491420497674]
# [37.0, 0.20749422784479066]
# [38.0, 0.18674480506031443]
# [39.0, 0.16807032455428583]
# [40.0, 0.1512632920988608]
# [41.0, 0.13613696288898325]
# [42.0, 0.1225232666000835]
# [43.0, 0.11027093994007942]
# [44.0, 0.09924384594607716]
# [45.0, 0.08931946135147939]
# [46.0, 0.08038751521633003]
# [47.0, 0.07234876369469134]
# [48.0, 0.06511388732522505]
# [49.0, 0.05860249859270539]
# [50.0, 0.05274224873343769]
# [51.0, 0.04746802386009108]
# [52.0, 0.04272122147408197]
# [53.0, 0.03844909932668372]
# [54.0, 0.03460418939401677]
# [55.0, 0.031143770454619357]
# [56.0, 0.02802939340917021]
# [57.0, 0.02522645406825319]
# [58.0, 0.02270380866142574]
# [59.0, 0.020433427795282455]
# [60.0, 0.018390085015759894]
# [61.0, 0.0165510765141903]
# [62.0, 0.014895968862774112]
# [63.0, 0.013406371976500964]
# [64.0, 0.012065734778850867]
# [65.0, 0.010859161300963649]
# [66.0, 0.009773245170869416]
# [67.0, 0.008795920653781764]
# [68.0, 0.00791632858840785]
# [69.0, 0.00712469572957275]
# [70.0, 0.006412226156619738]
# [71.0, 0.005771003540957054]
# [72.0, 0.0051939031868641905]
# [73.0, 0.0046745128681777715]
# [74.0, 0.004207061581368521]
# [75.0, 0.0037863554232444585]
# [76.0, 0.003407719880911486]
# [77.0, 0.0030669478928189164]
# [78.0, 0.0027602531035455513]
# [79.0, 0.002484227793203786]
# [80.0, 0.0022358050138819863]
# [81.0, 0.002012224512498051]
# [82.0, 0.0018110020612596145]
# [83.0, 0.001629901855132232]
# [84.0, 0.0014669116696168771]
# [85.0, 0.0013202205026487945]
# [86.0, 0.0011881984523967049]
# [87.0, 0.0010693786071627187]
# [88.0, 0.0009624407464485785]
# [89.0, 0.0008661966718079839]
# [90.0, 0.000779577004635712]
# [91.0, 0.0007016193041664565]
# [92.0, 0.0006314573737498108]
# [93.0, 0.0005683116363854879]
# [94.0, 0.0005114804727526234]
# [95.0, 0.0004603324254830454]
# [96.0, 0.0004142991829354514]
# [97.0, 0.00037286926464474845]
# [98.0, 0.00033558233818098415]
# [99.0, 0.00030202410437141225]
# [100.0, 0.00027182169394279754]
# [101.0, 0.00024463952455278104]
# [102.0, 0.00022017557209608185]
# [103.0, 0.0001981580148822104]
# [104.0, 0.00017834221340251588]
# [105.0, 0.00016050799206368538]
# [106.0, 0.000144457192860159]
# [107.0, 0.00013001147357272202]
# [108.0, 0.00011701032622113416]
# [109.0, 0.00010530929360186292]
# [110.0, 9.477836423599229e-5]

# %%
using Plots
plot(
    plot([wgrid wgrid],[vvec0 vvec]),
    plot([wgrid wgrid],[wvec0 wvec]),
    layout=(2,1),size=(800,600))
# Out:
#     Updating registry at `C:\Users\takeki\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:871
#   [2] wait()
#     @ Base .\task.jl:931
#   [3] uv_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1046
#   [4] unsafe_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1118
#   [5] unsafe_write
#     @ .\io.jl:419 [inlined]
#   [6] write
#     @ .\strings\io.jl:244 [inlined]
#   [7] print
#     @ .\strings\io.jl:246 [inlined]
#   [8] print(::IJulia.IJuliaStdio{Base.PipeEndpoint}, ::String, ::String, ::Vararg{String})
#     @ Base .\strings\io.jl:46
#   [9] println
#     @ .\strings\io.jl:75 [inlined]
#  [10] printpkgstyle(io::IJulia.IJuliaStdio{Base.PipeEndpoint}, cmd::Symbol, text::String, ignore_indent::Bool; color::Symbol)
#     @ Pkg C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\utils.jl:6
#  [11] printpkgstyle (repeats 2 times)
#     @ C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\utils.jl:2 [inlined]
#  [12] _resolve(io::IJulia.IJuliaStdio{Base.PipeEndpoint}, env::Pkg.Types.EnvCache, registries::Vector{Pkg.Registry.RegistryInstance}, pkgs::Vector{Pkg.Types.PackageSpec}, preserve::Pkg.Types.PreserveLevel, julia_version::VersionNumber)
#     @ Pkg.Operations C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\Operations.jl:1259
#  [13] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}, new_git::Set{Base.UUID}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform)
#     @ Pkg.Operations C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\Operations.jl:1276
#  [14] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, kwargs::Base.Pairs{Symbol, IJulia.IJuliaStdio{Base.PipeEndpoint}, Tuple{Symbol}, NamedTuple{(:io,), Tuple{IJulia.IJuliaStdio{Base.PipeEndpoint}}}})
#     @ Pkg.API C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:275
#  [15] add(pkgs::Vector{Pkg.Types.PackageSpec}; io::IJulia.IJuliaStdio{Base.PipeEndpoint}, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Pkg.API C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:156
#  [16] add(pkgs::Vector{Pkg.Types.PackageSpec})
#     @ Pkg.API C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:145
#  [17] #add#27
#     @ C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:144 [inlined]
#  [18] add
#     @ C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:144 [inlined]
#  [19] #add#26
#     @ C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:143 [inlined]
#  [20] add(pkg::String)
#     @ Pkg.API C:\Users\takeki\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:143
#  [21] top-level scope
#     @ In[6]:2
