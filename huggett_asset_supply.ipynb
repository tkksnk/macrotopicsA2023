# %%
using SparseArrays
using LinearAlgebra

# parameters
σ = 2.0 #1.2 #2.0   # CRRA utility with parameter s
r = -0.05 #0.035 #0.03  # interest rate
ρ = 0.05  # discount rate
z1 = .1
z2 = .2
z = [z1 z2]
λ1 = 1.5 #0.02 # arrival rate when z=z1
λ2 = 1.0 #0.03 # arrival rate when z=z2
λ = [λ1 λ2]

# number of grid points
na = 500
# set up the grid
amin = -0.15
amax = 10.0
a = collect(range(amin,stop=amax,length=na))
# distance between each grid
da = (amax-amin)/(na-1)

maxit = 20000 # maximum number of iterations
crit  = 1e-6; # convergence criteria

# %%
function vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta)

    na = size(a,1)
    amin = minimum(a)
    amax = maximum(a)
    da = (amax-amin)/(na-1)
    
    # for iteration
    dVf = zeros(na,2) # forward difference
    dVb = zeros(na,2) # backward difference
    c   = zeros(na,2) # optimal consumption (from dV)
    AT  = zeros(2*na,2*na)

    # (na,nz) matrix
    aa = [a a]
    zz = ones(na,1)*z

    Aswitch = [-sparse(I,na,na)*λ[1] sparse(I,na,na)*λ[1]; sparse(I,na,na)*λ[2] -sparse(I,na,na)*λ[2]]

    v = v0 # new v
    V = v  # old v

    dist  = zeros(maxit) # distance between old and new value functions at each iteration

    # MAIN LOOP
    for n in 1:maxit

        # forward difference
        dVf[1:na-1,:] = (V[2:na,:]-V[1:na-1,:])/da
    #     dVf[na,:] = (z .+ r.*amax).^(-σ) # state constraint, for stability with implicit method?
        dVf[na,:] = zeros(1,2) # will never be used (as s<0)
        # backward difference
        dVb[2:na,:] = (V[2:na,:]-V[1:na-1,:])/da
        dVb[1,:] = (z .+ r.*amin).^(-σ) # state constraint, for stability with implicit method?
    #     dVb[1] = zeros(1,2) # will never be used (as s>0)

        # consumption and savings with forward difference
        cf = dVf.^(-1/σ)
        sf = zz + r.*aa - cf
        # consumption and savings with backward difference
        cb = dVb.^(-1/σ)
        sb = zz + r.*aa - cb
        # consumption and derivative of value function at steady state (used for c only)
        c0  = zz + r.*aa
        dV0 = c0.^(-σ)

        # dV_upwind makes a choice of forward or backward differences based on
        # the sign of the drift    
        If = sf .> 0       # below steady state
        Ib = sb .< 0       # above steady state
        I0 = (1.0.-If.-Ib) # at steady state

        # make sure the right approximations are used at the boundaries
    #     # at ik = 1, s>0 -> f is used
    #     Ib[1] = 0 
    #     If[1] = 1
    #     # at ik = nk, s<0 -> b is used
        Ib[na,:] = ones(1,2)
        If[na,:] = zeros(1,2)

        dV_Upwind = dVf.*If + dVb.*Ib + dV0.*I0 # important to include third term    
        c = dV_Upwind.^(-1.0/σ)
        u = c.^(1.0-σ)/(1.0-σ)

        # CONSTRUCT MATRIX
        X = -sb.*Ib/da
        Y = -sf.*If/da + sb.*Ib/da
        Z = sf.*If/da

        A1 = spdiagm(na,na,[0 => Y[1:na,1]]...) + spdiagm(na,na,[-1 => X[2:na,1]]...) + spdiagm(na,na,[1 => Z[1:na-1,1]]...)
        A2 = spdiagm(na,na,[0 => Y[1:na,2]]...) + spdiagm(na,na,[-1 => X[2:na,2]]...) + spdiagm(na,na,[1 => Z[1:na-1,2]]...)
        A = [A1 spzeros(na,na); spzeros(na,na) A2] + Aswitch

        # implicit method, with sparse matrix
        B = (Delta*ρ + 1.0)*sparse(1.0I, 2*na, 2*na) - Delta*A
        u_stacked = [u[:,1]; u[:,2]]
        V_stacked = [V[:,1]; V[:,2]]
        b = Delta*u_stacked + V_stacked
        v_stacked = B\b # new v
        v = [v_stacked[1:na] v_stacked[na+1:2*na]]
        Vchange = V - v
        V = v

        dist[n] = maximum(abs.(Vchange))
#         if (mod(n,10)==0)
#             println([n,dist[n]])
#         end
        if dist[n]<crit
#             println("Value Function Converged, Iteration = ")
#             println(n)
            AT = A'
            break
        end
    end
    
    return v, c, AT
    
end
# Out:
# vfict_implicit (generic function with 1 method)

# %%
function fokker_planck(AT)

    # fokker-planck equation
    # AT = A'
    na = Int(size(AT,1)/2)
    
    b = zeros(2*na,1)

    # need to fix one value, otherwise matrix is singular
    i_fix = 1
    b[i_fix] = .1
    row = [zeros(1,i_fix-1) 1 zeros(1,2*na-i_fix)]
    AT[i_fix,:] = row

    # Solve linear system
    gg = AT\b
    g_sum = gg'*ones(2*na,1)*da
    gg = gg./g_sum

    g = [gg[1:na] gg[na+1:2*na]]
    

    return g
    
end
# Out:
# fokker_planck (generic function with 1 method)

# %%
# INITIAL GUESS
# v0 = (A.*k.^α).^(1.0-σ)/(1.0-σ)/ρ
v0 = zeros(na,2)
r = 0.01
v0[:,1] = (z[1] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ
v0[:,2] = (z[2] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ

Delta = 1000
@time v,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
@time g = fokker_planck(AT);
# Out:
#  16.292940 seconds (18.79 M allocations: 978.235 MiB, 8.73% gc time, 99.46% compilation time)
#   4.304367 seconds (5.51 M allocations: 272.810 MiB, 8.55% gc time, 99.90% compilation time)

# %%
nr = 20
rmin = -0.05
rmax = 0.04
rgrid = collect(range(rmin,stop=rmax,length=nr))
S = zeros(nr)

for ir in 1:nr
    
    r = rgrid[ir]
    @time v0,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
    @time g = fokker_planck(AT);    
    S[ir] = g[:,1]'*a*da + g[:,2]'*a*da

end
# Out:
#   0.071512 seconds (4.18 k allocations: 27.092 MiB, 38.49% gc time)
#   0.002289 seconds (90 allocations: 1.081 MiB)
#   0.023073 seconds (1.93 k allocations: 16.506 MiB)
#   0.002060 seconds (90 allocations: 1.081 MiB)
#   0.040521 seconds (1.96 k allocations: 16.507 MiB, 46.71% gc time)
#   0.002292 seconds (90 allocations: 1.081 MiB)
#   0.023042 seconds (1.93 k allocations: 16.506 MiB)
#   0.002263 seconds (90 allocations: 1.081 MiB)
#   0.040248 seconds (2.41 k allocations: 18.624 MiB, 28.21% gc time)
#   0.001880 seconds (90 allocations: 1.081 MiB)
#   0.023095 seconds (2.38 k allocations: 18.623 MiB)
#   0.001963 seconds (90 allocations: 1.081 MiB)
#   0.027881 seconds (2.38 k allocations: 18.623 MiB)
#   0.002211 seconds (90 allocations: 1.081 MiB)
#   0.034312 seconds (2.41 k allocations: 18.625 MiB, 27.55% gc time)
#   0.001737 seconds (90 allocations: 1.081 MiB)
#   0.026424 seconds (2.38 k allocations: 18.623 MiB)
#   0.002426 seconds (90 allocations: 1.081 MiB)
#   0.033129 seconds (2.41 k allocations: 18.625 MiB, 19.01% gc time)
#   0.002100 seconds (90 allocations: 1.081 MiB)
#   0.024763 seconds (2.38 k allocations: 18.624 MiB)
#   0.002259 seconds (90 allocations: 1.081 MiB)
#   0.033000 seconds (2.41 k allocations: 18.626 MiB, 15.72% gc time)
#   0.002048 seconds (90 allocations: 1.081 MiB)
#   0.024434 seconds (2.38 k allocations: 18.624 MiB)
#   0.001751 seconds (90 allocations: 1.081 MiB)
#   0.026350 seconds (2.38 k allocations: 18.624 MiB)
#   0.002248 seconds (90 allocations: 1.081 MiB)
#   0.031524 seconds (2.41 k allocations: 18.626 MiB, 21.89% gc time)
#   0.001744 seconds (90 allocations: 1.081 MiB)
#   0.025368 seconds (2.38 k allocations: 18.625 MiB)
#   0.002253 seconds (90 allocations: 1.081 MiB)
#   0.036099 seconds (2.41 k allocations: 18.627 MiB, 22.29% gc time)
#   0.001696 seconds (90 allocations: 1.082 MiB)
#   0.026064 seconds (2.38 k allocations: 18.627 MiB)
#   0.002170 seconds (90 allocations: 1.082 MiB)
#   0.033633 seconds (2.41 k allocations: 18.632 MiB, 15.35% gc time)
#   0.002260 seconds (90 allocations: 1.084 MiB)
#   0.025068 seconds (2.38 k allocations: 18.642 MiB)
#   0.001921 seconds (90 allocations: 1.089 MiB)

# %%
using Plots
plot(S,rgrid)
